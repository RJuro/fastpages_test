# %% [markdown]
# # "This and that"
# > "I'm in a meeting :-) Yeah!"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: false
# - categories: [fastpages, jupyter]
# - hide: false

# %%
#hide

import pandas as pd
import seaborn as sns
sns.set(color_codes=True, rc={'figure.figsize':(10,8)})

from IPython.display import HTML #Youtube embed

# %% [markdown]
# > youtube: https://youtu.be/QS5jpQ6cpsg

# %%
#collapse

# load the dataset from GitHub - original source

penguins = pd.read_csv("https://github.com/allisonhorst/palmerpenguins/raw/5b5891f01b52ae26ad8cb9755ec93672f49328a8/data/penguins_size.csv")

# %%
#hide_input

penguins.head()
# Out:
#   species_short     island  culmen_length_mm  culmen_depth_mm  \
# 0        Adelie  Torgersen              39.1             18.7
# 1        Adelie  Torgersen              39.5             17.4
# 2        Adelie  Torgersen              40.3             18.0
# 4        Adelie  Torgersen              36.7             19.3
# 5        Adelie  Torgersen              39.3             20.6
#
#    flipper_length_mm  body_mass_g     sex
# 0              181.0       3750.0    MALE
# 1              186.0       3800.0  FEMALE
# 2              195.0       3250.0  FEMALE
# 4              193.0       3450.0  FEMALE
# 5              190.0       3650.0    MALE

# %%
# drop all missing observations and count up the birds for each species

penguins = penguins.dropna()
penguins.species_short.value_counts()
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species_short, dtype: int64

# %% [markdown]
# ![](https://github.com/allisonhorst/palmerpenguins/raw/master/man/figures/culmen_depth.png)

# %%
#hide_input

# Let's check out the data visually

sns.pairplot(penguins, hue='species_short', kind="reg", markers=["o", "s", "D"], plot_kws={'line_kws':{'color':'white'}})
